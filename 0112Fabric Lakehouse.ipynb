# %% [markdown]
# # Fabric Lakehouse

# %% [markdown]
# ## 1. Create a Microsoft Fabric lakehouse
# [Link](https://microsoftlearning.github.io/mslearn-fabric/Instructions/Labs/01-lakehouse.html) ancient robot

# %%
1. Create a Workspace > Lakehouse
2. Upload a file
3. Explore Shortcuts
4. Load file data into a table
5. Use SQL to query tables
6. Create a Visual Query

# %% [markdown]
# ## 2. Analyze data with Apache Spark
# [Link](https://microsoftlearning.github.io/mslearn-fabric/Instructions/Labs/02-analyze-spark.html) brazilian kiwi

# %%
1. Create a Workspace > Lakehouse > Upload files
2. Create a notebook
3. Create a Dataframe
- use table schema
- use wildcard option for selecting multiple files
4. Explore data in a dataframe
- filter, aggregate and group by
5. Use Spark to transform data files
- Use DataFrame methods and functions
- Save the transformed data, partitioned data
6. Work with tables and SQL
- .saveAsTable(), Run SQL code in a cell
7. Visualize data with Spark

# %% [markdown]
# ## 3. Use delta tables in Apache Spark
# [Link](https://microsoftlearning.github.io/mslearn-fabric/Instructions/Labs/03-delta-lake.html)

# %%
1. Create a Workspace > Lakehouse > Upload files
2. Explore data in a dataframe
3. Create Delta Tables
- managed table, external table
4. Use SQL to create a Delta Table
5. Explore table versioning
6. Analyse Delta table data with SQL queries
7. Use Delta tables for streaming data

# %% [markdown]
# ## 4. Ingest data with a pipeline in Microsoft Fabric
# [Link](https://microsoftlearning.github.io/mslearn-fabric/Instructions/Labs/04-ingest-pipeline.html) daringigloo

# %%
1. Create a Workspace > Lakehouse
2. Create a pipeline
- Copy data activity
3. Create a notebook
4. Modify the pipeline

# %% [markdown]
# ## 5. Create and use Dataflows (Gen2) in Microsoft Fabric
# [Link](https://microsoftlearning.github.io/mslearn-fabric/Instructions/Labs/05-dataflows-gen2.html) electic panda

# %%
1. Create a Workspace > Lakehouse
2. Create a Dataflow Gen2 to ingest data
3. Add data destination for Dataflow
4. Add a dataflow to a pipeline

# %% [markdown]
# ## 6. Analyze data in a data warehouse
# [Link](https://microsoftlearning.github.io/mslearn-fabric/Instructions/Labs/06-data-warehouse.html)

# %%
1. Create a Workspace
2. Create a data warehouse
3. Create tables and insert data
4. Query data warehouse tables
5. Create a view
6. Create a visual query
7. Define a data model
