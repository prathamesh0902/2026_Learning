# %%
# %sql
Personal introduction

price modelling experience?
>> No

n X n data. is it a good data

>> no. do feature importance / feature selection PCA
>> for rows do EDA, missing values, outlier detection, scaling

ideal number for n features e.g. 1000 rows for 10 columns
>> column variance not 0 for model training
>> tasks like binary classification, sentiment analysis might require less rows

how to test that the model is training well
>> Cross validation

explain heteroscedacity in real terms
>> errors fan out or converge in wrt X
>> Linear assumption is invalid


R squared value = 95%. when is this not true
>> model overfitting

p value 0.049 and 0.051. threshold 0.05
what other things to consider?
>> normality assumption, size of data
>> consider proportion test than just numbers alone

Span vs non spam filtering. Accuracy = 95% but not filtering correct

>> Consider Precision as main metric
>> Precision vs Recall cost or finding vs customer getting a bad experience
>> External methods Third party filtering

How many flights from IGI airport daily
>> Population based and then filtering
>> Tier 1 - 5 cities * 6 flights
>> Tier 2 - 10 cities * 3 flights
>> Tier 3 - 30 cities * 1 flight

# %% [markdown]
# Round 2

# %%
Do you have experience in prediciton modelling?
